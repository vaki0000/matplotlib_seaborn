# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import numpy as np

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.catplot(x="pclass", y="survived", data=titanic, kind="bar");

# %%
sns.catplot(x="pclass", y="survived", data=titanic, kind="bar", estimator=np.sum);

# %%
sns.catplot(x="pclass", y="survived", data=titanic, kind="bar", estimator=np.sum, hue="sex");

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x="day", kind ="count", data=tips, col="smoker");

# %%
sns.catplot(x="day", kind ="count", data=tips, col="smoker", row="sex");

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic["alone"].value_counts()
# Out:
# True     537
# False    354
# Name: alone, dtype: int64

# %%
titanic["embark_town"].value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
sns.catplot(x="class", 
           data=titanic,
           kind="count",
           row="alone",
           col="embark_town");

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="box");

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="box", hue="smoker");

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="violin");

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="swarm", hue="sex", dodge=True);

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg");

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="kde");

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex");

# %%
sns.pairplot(tips);

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.pairplot(titanic);
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
sns.color_palette("viridis", 10)
# Out:
# [(0.283072, 0.130895, 0.449241),
#  (0.262138, 0.242286, 0.520837),
#  (0.220057, 0.343307, 0.549413),
#  (0.177423, 0.437527, 0.557565),
#  (0.143343, 0.522773, 0.556295),
#  (0.119512, 0.607464, 0.540218),
#  (0.166383, 0.690856, 0.496502),
#  (0.319809, 0.770914, 0.411152),
#  (0.525776, 0.833491, 0.288127),
#  (0.762373, 0.876424, 0.137064)]

# %%
sns.pairplot(tips, hue="sex", palette="viridis");

# %%
sns.pairplot(tips, hue="sex", palette="gist_rainbow", corner=True);

# %%
sns.pairplot(tips, hue="sex", palette="ocean_r", corner=True, diag_kind="hist")

# %%
g = sns.PairGrid(tips)
g.map(sns.scatterplot);

# %%
g = sns.PairGrid(tips)
g.map_upper(sns.scatterplot)
g.map_diag(sns.histplot);

# %%
g = sns.PairGrid(tips)
g.map_upper(sns.scatterplot)
g.map_diag(sns.histplot)
g.map_lower(sns.kdeplot, colors="red");

# %%
g = sns.PairGrid(tips, hue="sex", palette="magma")
g.map_upper(sns.scatterplot, s=100, edgecolor="black")
g.map_diag(sns.histplot)
g.map_lower(sns.kdeplot)
g.add_legend();

# %%
g = sns.FacetGrid(data=tips, col="time", row="smoker")
g.map(sns.histplot, "total_bill");

# %%
g = sns.FacetGrid(data=tips, col="time", row="smoker")
g.map(sns.histplot, "total_bill", "tip");

# %%
g = sns.FacetGrid(data=tips, col="time", row="smoker")
g.map(plt.scatter, "total_bill", "tip");

# %%
g = sns.FacetGrid(data=tips, col="time", row="smoker", hue="sex")
g.map(plt.scatter, "total_bill", "tip")
g.add_legend();

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.heatmap(tips.corr());

# %%
sns.heatmap(tips.corr(), annot=True);

# %%
sns.heatmap(tips.corr(), annot=True, cmap="viridis");

# %%
sns.heatmap(tips.corr(), annot=True, cmap="viridis", center=1
           );

# %%
sns.heatmap(tips.corr(), annot=True, cmap="viridis", center=0.5);

# %%
sns.heatmap(tips.corr(), annot=True, cmap="viridis", center=0);

# %%
sns.heatmap(tips.corr(), annot=True, cmap="coolwarm", vmin=-1, vmax=1);

# %%
sns.heatmap(tips.corr(), annot=True, cmap="coolwarm_r", vmin=-1, vmax=1);

# %%
mask = np.triu(tips.corr())
sns.heatmap(tips.corr(), annot=True, cmap="Spectral", vmin=-1, vmax=1, mask=mask );

# %%
mask = np.triu(titanic.corr())
sns.heatmap(titanic.corr(), annot=True, cmap="coolwarm", vmin=-1, vmax=1, mask=mask );

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
penguins.isnull()
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False            True           True               True
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex
# 0          False  False
# 1          False  False
# 2          False  False
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(penguins.isnull(), cmap="ocean_r", vmin=-0.1);

# %%
sns.clustermap(tips.corr(), annot=True);

# %%
sns.clustermap(tips.corr(), annot=True, figsize=(5,5));

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris = iris.iloc[:,0:-1]
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
sns.clustermap(iris);
